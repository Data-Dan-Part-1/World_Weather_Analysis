# %%
# Import the dependencies.
import pandas as pd
import json
import random
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
from datetime import datetime
from scipy.stats import linregress

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

# %%
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    if city not in cities:
        cities.append(city)

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval      ")
print("------------------------------")

#Create counters
record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i %50 == 0 and i >=50):
        set_count += 1
        record_count = 1
    city_url = url + "&q=" + city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
 # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_conditions = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Conditions": city_conditions})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    
    try:
        city_conditions = "Rain"
        
        
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------------
# Processing Record 1 of Set 1 | atuona
# Processing Record 2 of Set 1 | hilo
# Processing Record 3 of Set 1 | barrow
# Processing Record 4 of Set 1 | codo
# Processing Record 5 of Set 1 | santa isabel do rio negro
# Processing Record 6 of Set 1 | cape town
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | avarua
# Processing Record 9 of Set 1 | kiunga
# Processing Record 10 of Set 1 | port-cartier
# Processing Record 11 of Set 1 | yaan
# Processing Record 12 of Set 1 | qaanaaq
# Processing Record 13 of Set 1 | nome
# Processing Record 14 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | mujiayingzi
# Processing Record 18 of Set 1 | santa isabel
# Processing Record 19 of Set 1 | mataura
# Processing Record 20 of Set 1 | new norfolk
# Processing Record 21 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 1 | ponta do sol
# Processing Record 23 of Set 1 | mahenge
# Processing Record 24 of Set 1 | yirol
# City not found. Skipping...
# Processing Record 25 of Set 1 | ballina
# Processing Record 26 of Set 1 | havre-saint-pierre
# Processing Record 27 of Set 1 | rikitea
# Processing Record 28 of Set 1 | boa vista
# Processing Record 29 of Set 1 | east london
# Processing Record 30 of Set 1 | macusani
# Processing Record 31 of Set 1 | khatanga
# Processing Record 32 of Set 1 | yellowknife
# Processing Record 33 of Set 1 | labutta
# City not found. Skipping...
# Processing Record 34 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 1 | nurota
# Processing Record 36 of Set 1 | tuggurt
# City not found. Skipping...
# Processing Record 37 of Set 1 | itarema
# Processing Record 38 of Set 1 | whitehorse
# Processing Record 39 of Set 1 | bara
# Processing Record 40 of Set 1 | vaini
# Processing Record 41 of Set 1 | buala
# Processing Record 42 of Set 1 | pemangkat
# Processing Record 43 of Set 1 | shahr-e kord
# Processing Record 44 of Set 1 | dikson
# Processing Record 45 of Set 1 | ahipara
# Processing Record 46 of Set 1 | jamestown
# Processing Record 47 of Set 1 | kununurra
# Processing Record 48 of Set 1 | lyngseidet
# Processing Record 49 of Set 1 | isangel
# Processing Record 50 of Set 1 | iqaluit
# Processing Record 1 of Set 2 | nkayi
# Processing Record 2 of Set 2 | husavik
# Processing Record 3 of Set 2 | korgen
# Processing Record 4 of Set 2 | kodinar
# Processing Record 5 of Set 2 | arraial do cabo
# Processing Record 6 of Set 2 | hithadhoo
# Processing Record 7 of Set 2 | quatre cocos
# Processing Record 8 of Set 2 | killam
# Processing Record 9 of Set 2 | faya
# Processing Record 10 of Set 2 | evensk
# Processing Record 11 of Set 2 | narsaq
# Processing Record 12 of Set 2 | cidreira
# Processing Record 13 of Set 2 | stornoway
# Processing Record 14 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 2 | coahuayana
# Processing Record 16 of Set 2 | biak
# Processing Record 17 of Set 2 | mar del plata
# Processing Record 18 of Set 2 | pitimbu
# Processing Record 19 of Set 2 | carnarvon
# Processing Record 20 of Set 2 | guerrero negro
# Processing Record 21 of Set 2 | la serena
# Processing Record 22 of Set 2 | san martin
# Processing Record 23 of Set 2 | jibuti
# Processing Record 24 of Set 2 | tongliao
# Processing Record 25 of Set 2 | kapaa
# Processing Record 26 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 2 | xuddur
# Processing Record 28 of Set 2 | odienne
# Processing Record 29 of Set 2 | tiksi
# Processing Record 30 of Set 2 | rondonopolis
# Processing Record 31 of Set 2 | talnakh
# Processing Record 32 of Set 2 | severo-kurilsk
# Processing Record 33 of Set 2 | skjervoy
# Processing Record 34 of Set 2 | friesach
# Processing Record 35 of Set 2 | seymchan
# Processing Record 36 of Set 2 | dinsor
# City not found. Skipping...
# Processing Record 37 of Set 2 | beian
# Processing Record 38 of Set 2 | bethel
# Processing Record 39 of Set 2 | pisco
# Processing Record 40 of Set 2 | saskylakh
# Processing Record 41 of Set 2 | havelock
# Processing Record 42 of Set 2 | leningradskiy
# Processing Record 43 of Set 2 | naica
# Processing Record 44 of Set 2 | avera
# Processing Record 45 of Set 2 | agirish
# Processing Record 46 of Set 2 | portage
# Processing Record 47 of Set 2 | puerto ayora
# Processing Record 48 of Set 2 | lebu
# Processing Record 49 of Set 2 | georgetown
# Processing Record 50 of Set 2 | bluff
# Processing Record 1 of Set 3 | chokurdakh
# Processing Record 2 of Set 3 | antalaha
# Processing Record 3 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 4 of Set 3 | mayor pablo lagerenza
# Processing Record 5 of Set 3 | tuktoyaktuk
# Processing Record 6 of Set 3 | albany
# Processing Record 7 of Set 3 | hunza
# City not found. Skipping...
# Processing Record 8 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 3 | hualmay
# Processing Record 10 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 3 | bani
# Processing Record 12 of Set 3 | tautira
# Processing Record 13 of Set 3 | geraldton
# Processing Record 14 of Set 3 | kodiak
# Processing Record 15 of Set 3 | padang
# Processing Record 16 of Set 3 | ilulissat
# Processing Record 17 of Set 3 | keighley
# Processing Record 18 of Set 3 | yulara
# Processing Record 19 of Set 3 | butaritari
# Processing Record 20 of Set 3 | upernavik
# Processing Record 21 of Set 3 | ribeira brava
# Processing Record 22 of Set 3 | uvira
# Processing Record 23 of Set 3 | vila franca do campo
# Processing Record 24 of Set 3 | namatanai
# Processing Record 25 of Set 3 | bredasdorp
# Processing Record 26 of Set 3 | roald
# Processing Record 27 of Set 3 | bathsheba
# Processing Record 28 of Set 3 | coquimbo
# Processing Record 29 of Set 3 | umm lajj
# Processing Record 30 of Set 3 | boca do acre
# Processing Record 31 of Set 3 | victoria
# Processing Record 32 of Set 3 | turayf
# Processing Record 33 of Set 3 | collie
# Processing Record 34 of Set 3 | hobart
# Processing Record 35 of Set 3 | timberlake
# Processing Record 36 of Set 3 | lagoa
# Processing Record 37 of Set 3 | souillac
# Processing Record 38 of Set 3 | vao
# Processing Record 39 of Set 3 | zaysan
# Processing Record 40 of Set 3 | saint-philippe
# Processing Record 41 of Set 3 | la rioja
# Processing Record 42 of Set 3 | luderitz
# Processing Record 43 of Set 3 | margate
# Processing Record 44 of Set 3 | la seyne-sur-mer
# Processing Record 45 of Set 3 | norman wells
# Processing Record 46 of Set 3 | port hardy
# Processing Record 47 of Set 3 | esperance
# Processing Record 48 of Set 3 | matara
# Processing Record 49 of Set 3 | shimoda
# Processing Record 50 of Set 3 | palmer
# Processing Record 1 of Set 4 | puerto madryn
# Processing Record 2 of Set 4 | wanaka
# Processing Record 3 of Set 4 | kruisfontein
# Processing Record 4 of Set 4 | tank
# Processing Record 5 of Set 4 | port alfred
# Processing Record 6 of Set 4 | takoradi
# Processing Record 7 of Set 4 | green river
# Processing Record 8 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 9 of Set 4 | biskupiec
# Processing Record 10 of Set 4 | touros
# Processing Record 11 of Set 4 | waldshut-tiengen
# Processing Record 12 of Set 4 | port hedland
# Processing Record 13 of Set 4 | alekseyevsk
# Processing Record 14 of Set 4 | kaitangata
# Processing Record 15 of Set 4 | sao felix do xingu
# Processing Record 16 of Set 4 | provideniya
# Processing Record 17 of Set 4 | vila velha
# Processing Record 18 of Set 4 | saint george
# Processing Record 19 of Set 4 | yecla
# Processing Record 20 of Set 4 | cutzamala
# City not found. Skipping...
# Processing Record 21 of Set 4 | marovoay
# Processing Record 22 of Set 4 | torbay
# Processing Record 23 of Set 4 | tasiilaq
# Processing Record 24 of Set 4 | nikolskoye
# Processing Record 25 of Set 4 | cheuskiny
# City not found. Skipping...
# Processing Record 26 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 27 of Set 4 | dandong
# Processing Record 28 of Set 4 | cabo san lucas
# Processing Record 29 of Set 4 | dudinka
# Processing Record 30 of Set 4 | rajapur
# Processing Record 31 of Set 4 | sitka
# Processing Record 32 of Set 4 | aguimes
# Processing Record 33 of Set 4 | la ronge
# Processing Record 34 of Set 4 | puerto suarez
# Processing Record 35 of Set 4 | saint anthony
# Processing Record 36 of Set 4 | zarubino
# Processing Record 37 of Set 4 | beringovskiy
# Processing Record 38 of Set 4 | clyde river
# Processing Record 39 of Set 4 | port elizabeth
# Processing Record 40 of Set 4 | tubuala
# Processing Record 41 of Set 4 | hermanus
# Processing Record 42 of Set 4 | kegayli
# City not found. Skipping...
# Processing Record 43 of Set 4 | bambous virieux
# Processing Record 44 of Set 4 | kaspiyskiy
# Processing Record 45 of Set 4 | ulundi
# Processing Record 46 of Set 4 | qandala
# Processing Record 47 of Set 4 | marawi
# Processing Record 48 of Set 4 | airai
# Processing Record 49 of Set 4 | lakes entrance
# Processing Record 50 of Set 4 | araouane
# Processing Record 1 of Set 5 | pokhara
# Processing Record 2 of Set 5 | bodden town
# Processing Record 3 of Set 5 | koutsouras
# Processing Record 4 of Set 5 | abalak
# Processing Record 5 of Set 5 | chicama
# Processing Record 6 of Set 5 | gao
# Processing Record 7 of Set 5 | ulcinj
# Processing Record 8 of Set 5 | aras
# Processing Record 9 of Set 5 | ribeira grande
# Processing Record 10 of Set 5 | norwich
# Processing Record 11 of Set 5 | kadykchan
# City not found. Skipping...
# Processing Record 12 of Set 5 | lata
# Processing Record 13 of Set 5 | lipin bor
# Processing Record 14 of Set 5 | posyet
# Processing Record 15 of Set 5 | oranjemund
# Processing Record 16 of Set 5 | loei
# Processing Record 17 of Set 5 | labuhan
# Processing Record 18 of Set 5 | arlit
# Processing Record 19 of Set 5 | saldanha
# Processing Record 20 of Set 5 | itaituba
# Processing Record 21 of Set 5 | flin flon
# Processing Record 22 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 5 | maracas
# Processing Record 24 of Set 5 | kangaatsiaq
# Processing Record 25 of Set 5 | kupang
# Processing Record 26 of Set 5 | praia da vitoria
# Processing Record 27 of Set 5 | adzope
# Processing Record 28 of Set 5 | skotterud
# Processing Record 29 of Set 5 | eskasem
# City not found. Skipping...
# Processing Record 30 of Set 5 | swan hill
# Processing Record 31 of Set 5 | gouyave
# Processing Record 32 of Set 5 | benalla
# Processing Record 33 of Set 5 | olean
# Processing Record 34 of Set 5 | lorengau
# Processing Record 35 of Set 5 | ouesso
# Processing Record 36 of Set 5 | iquitos
# Processing Record 37 of Set 5 | kieta
# Processing Record 38 of Set 5 | rudnyy
# Processing Record 39 of Set 5 | panzhihua
# Processing Record 40 of Set 5 | solwezi
# Processing Record 41 of Set 5 | stromness
# Processing Record 42 of Set 5 | kozienice
# Processing Record 43 of Set 5 | boddam
# Processing Record 44 of Set 5 | kavaratti
# Processing Record 45 of Set 5 | fairbanks
# Processing Record 46 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 47 of Set 5 | camana
# Processing Record 48 of Set 5 | meulaboh
# Processing Record 49 of Set 5 | puerto carreno
# Processing Record 50 of Set 5 | villiers
# Processing Record 1 of Set 6 | sofiysk
# City not found. Skipping...
# Processing Record 2 of Set 6 | adrar
# Processing Record 3 of Set 6 | tessalit
# Processing Record 4 of Set 6 | kismayo
# Processing Record 5 of Set 6 | chapais
# Processing Record 6 of Set 6 | alofi
# Processing Record 7 of Set 6 | filingue
# Processing Record 8 of Set 6 | birjand
# Processing Record 9 of Set 6 | zyryanka
# Processing Record 10 of Set 6 | yomitan
# City not found. Skipping...
# Processing Record 11 of Set 6 | dien bien
# City not found. Skipping...
# Processing Record 12 of Set 6 | scarborough
# Processing Record 13 of Set 6 | wang saphung
# Processing Record 14 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 6 | eyl
# Processing Record 16 of Set 6 | solnechnyy
# Processing Record 17 of Set 6 | gat
# Processing Record 18 of Set 6 | pacifica
# Processing Record 19 of Set 6 | lavrentiya
# Processing Record 20 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 21 of Set 6 | xining
# Processing Record 22 of Set 6 | olinda
# Processing Record 23 of Set 6 | takaka
# Processing Record 24 of Set 6 | port blair
# Processing Record 25 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 26 of Set 6 | clinton
# Processing Record 27 of Set 6 | fevralsk
# City not found. Skipping...
# Processing Record 28 of Set 6 | manzil tamim
# City not found. Skipping...
# Processing Record 29 of Set 6 | wasilla
# Processing Record 30 of Set 6 | newport
# Processing Record 31 of Set 6 | kaeo
# Processing Record 32 of Set 6 | richards bay
# Processing Record 33 of Set 6 | sungairaya
# Processing Record 34 of Set 6 | tuatapere
# Processing Record 35 of Set 6 | castro
# Processing Record 36 of Set 6 | port lincoln
# Processing Record 37 of Set 6 | qasigiannguit
# Processing Record 38 of Set 6 | nombre de dios
# Processing Record 39 of Set 6 | kirgiz-miyaki
# Processing Record 40 of Set 6 | norilsk
# Processing Record 41 of Set 6 | pordim
# Processing Record 42 of Set 6 | bandarbeyla
# Processing Record 43 of Set 6 | ratnagiri
# Processing Record 44 of Set 6 | daru
# Processing Record 45 of Set 6 | romny
# Processing Record 46 of Set 6 | ozernovskiy
# Processing Record 47 of Set 6 | chala
# Processing Record 48 of Set 6 | kalmunai
# Processing Record 49 of Set 6 | brestovat
# City not found. Skipping...
# Processing Record 50 of Set 6 | asayita
# City not found. Skipping...
# Processing Record 1 of Set 7 | arkadelphia
# Processing Record 2 of Set 7 | dunedin
# Processing Record 3 of Set 7 | teotitlan
# Processing Record 4 of Set 7 | the pas
# Processing Record 5 of Set 7 | dzaoudzi
# Processing Record 6 of Set 7 | puerto escondido
# Processing Record 7 of Set 7 | aanekoski
# Processing Record 8 of Set 7 | gizo
# Processing Record 9 of Set 7 | ourem
# Processing Record 10 of Set 7 | kichera
# Processing Record 11 of Set 7 | sulangan
# Processing Record 12 of Set 7 | san patricio
# Processing Record 13 of Set 7 | cherskiy
# Processing Record 14 of Set 7 | verkhoyansk
# Processing Record 15 of Set 7 | mondovi
# Processing Record 16 of Set 7 | ranong
# Processing Record 17 of Set 7 | cosolapa
# Processing Record 18 of Set 7 | north auburn
# Processing Record 19 of Set 7 | rundu
# Processing Record 20 of Set 7 | chulym
# Processing Record 21 of Set 7 | anzio
# Processing Record 22 of Set 7 | sao filipe
# Processing Record 23 of Set 7 | zhanaozen
# Processing Record 24 of Set 7 | dukat
# Processing Record 25 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 7 | la primavera
# Processing Record 27 of Set 7 | mirabad
# Processing Record 28 of Set 7 | mahebourg
# Processing Record 29 of Set 7 | half moon bay
# Processing Record 30 of Set 7 | berlevag
# Processing Record 31 of Set 7 | cabedelo
# Processing Record 32 of Set 7 | muzhi
# Processing Record 33 of Set 7 | la palma
# Processing Record 34 of Set 7 | luwuk
# Processing Record 35 of Set 7 | arequipa
# Processing Record 36 of Set 7 | uusikaupunki
# Processing Record 37 of Set 7 | salalah
# Processing Record 38 of Set 7 | diamantino
# Processing Record 39 of Set 7 | khorixas
# Processing Record 40 of Set 7 | belyy yar
# Processing Record 41 of Set 7 | tyup
# Processing Record 42 of Set 7 | faanui
# Processing Record 43 of Set 7 | ginir
# Processing Record 44 of Set 7 | thinadhoo
# Processing Record 45 of Set 7 | micheweni
# Processing Record 46 of Set 7 | kamiiso
# Processing Record 47 of Set 7 | ostrovnoy
# Processing Record 48 of Set 7 | la paz
# Processing Record 49 of Set 7 | tenenkou
# Processing Record 50 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 8 | kanye
# Processing Record 2 of Set 8 | tarauaca
# Processing Record 3 of Set 8 | sao domingos do maranhao
# Processing Record 4 of Set 8 | vostok
# Processing Record 5 of Set 8 | san cristobal
# Processing Record 6 of Set 8 | pella
# Processing Record 7 of Set 8 | te anau
# Processing Record 8 of Set 8 | mulchen
# Processing Record 9 of Set 8 | bumba
# Processing Record 10 of Set 8 | maniwaki
# Processing Record 11 of Set 8 | klaksvik
# Processing Record 12 of Set 8 | cauquenes
# Processing Record 13 of Set 8 | nuqui
# Processing Record 14 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 15 of Set 8 | fortuna
# Processing Record 16 of Set 8 | mogadishu
# Processing Record 17 of Set 8 | asau
# Processing Record 18 of Set 8 | birao
# Processing Record 19 of Set 8 | mokrous
# Processing Record 20 of Set 8 | mazinde
# Processing Record 21 of Set 8 | stockelsdorf
# Processing Record 22 of Set 8 | vilcun
# Processing Record 23 of Set 8 | jamui
# Processing Record 24 of Set 8 | palm coast
# Processing Record 25 of Set 8 | ejutla de crespo
# Processing Record 26 of Set 8 | fallon
# Processing Record 27 of Set 8 | bubaque
# Processing Record 28 of Set 8 | necochea
# Processing Record 29 of Set 8 | pleasanton
# Processing Record 30 of Set 8 | el alto
# Processing Record 31 of Set 8 | nkhata bay
# Processing Record 32 of Set 8 | greystones
# Processing Record 33 of Set 8 | mamu kanjan
# Processing Record 34 of Set 8 | maniitsoq
# Processing Record 35 of Set 8 | comodoro rivadavia
# Processing Record 36 of Set 8 | pevek
# Processing Record 37 of Set 8 | sangmelima
# Processing Record 38 of Set 8 | karakendzha
# City not found. Skipping...
# Processing Record 39 of Set 8 | laguna
# Processing Record 40 of Set 8 | moose factory
# Processing Record 41 of Set 8 | yian
# City not found. Skipping...
# Processing Record 42 of Set 8 | dzhebariki-khaya
# Processing Record 43 of Set 8 | vitim
# Processing Record 44 of Set 8 | namibe
# Processing Record 45 of Set 8 | shevchenkove
# Processing Record 46 of Set 8 | kabo
# Processing Record 47 of Set 8 | brae
# Processing Record 48 of Set 8 | grand gaube
# Processing Record 49 of Set 8 | lensk
# Processing Record 50 of Set 8 | uruguaiana
# Processing Record 1 of Set 9 | aklavik
# Processing Record 2 of Set 9 | bengkulu
# Processing Record 3 of Set 9 | san gavino monreale
# Processing Record 4 of Set 9 | grindavik
# Processing Record 5 of Set 9 | chuy
# Processing Record 6 of Set 9 | port hawkesbury
# Processing Record 7 of Set 9 | colares
# Processing Record 8 of Set 9 | karagaylinskiy
# Processing Record 9 of Set 9 | mucurapo
# Processing Record 10 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 9 | tazmalt
# Processing Record 12 of Set 9 | anadyr
# Processing Record 13 of Set 9 | saint-pierre
# Processing Record 14 of Set 9 | verkhnevilyuysk
# Processing Record 15 of Set 9 | abu dhabi
# Processing Record 16 of Set 9 | kazanka
# Processing Record 17 of Set 9 | si racha
# Processing Record 18 of Set 9 | koulikoro
# Processing Record 19 of Set 9 | saint-augustin
# Processing Record 20 of Set 9 | port harcourt
# Processing Record 21 of Set 9 | fernandina beach
# Processing Record 22 of Set 9 | tornio
# Processing Record 23 of Set 9 | kayes
# Processing Record 24 of Set 9 | abha
# Processing Record 25 of Set 9 | bilma
# Processing Record 26 of Set 9 | paita
# Processing Record 27 of Set 9 | kloulklubed
# Processing Record 28 of Set 9 | qui nhon
# Processing Record 29 of Set 9 | srednekolymsk
# Processing Record 30 of Set 9 | la cumbre
# Processing Record 31 of Set 9 | fort-shevchenko
# Processing Record 32 of Set 9 | aktau
# Processing Record 33 of Set 9 | khandbari
# Processing Record 34 of Set 9 | itacoatiara
# Processing Record 35 of Set 9 | babanusah
# City not found. Skipping...
# Processing Record 36 of Set 9 | moussoro
# Processing Record 37 of Set 9 | birin
# Processing Record 38 of Set 9 | bose
# Processing Record 39 of Set 9 | okha
# Processing Record 40 of Set 9 | altay
# Processing Record 41 of Set 9 | malinovoye ozero
# Processing Record 42 of Set 9 | plouzane
# Processing Record 43 of Set 9 | mackay
# Processing Record 44 of Set 9 | temaraia
# City not found. Skipping...
# Processing Record 45 of Set 9 | ankang
# Processing Record 46 of Set 9 | itanagar
# Processing Record 47 of Set 9 | turukhansk
# Processing Record 48 of Set 9 | baker city
# Processing Record 49 of Set 9 | hervey bay
# Processing Record 50 of Set 9 | ancud
# Processing Record 1 of Set 10 | gazanjyk
# Processing Record 2 of Set 10 | ixtapa
# Processing Record 3 of Set 10 | gamba
# Processing Record 4 of Set 10 | alice springs
# Processing Record 5 of Set 10 | terre haute
# Processing Record 6 of Set 10 | nassau
# Processing Record 7 of Set 10 | lovozero
# Processing Record 8 of Set 10 | pio ix
# Processing Record 9 of Set 10 | sabla
# Processing Record 10 of Set 10 | manuk mangkaw
# Processing Record 11 of Set 10 | neuquen
# Processing Record 12 of Set 10 | keti bandar
# Processing Record 13 of Set 10 | sur
# Processing Record 14 of Set 10 | yabrud
# Processing Record 15 of Set 10 | tabas
# Processing Record 16 of Set 10 | hofn
# Processing Record 17 of Set 10 | gorin
# Processing Record 18 of Set 10 | wanning
# Processing Record 19 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 20 of Set 10 | naryan-mar
# Processing Record 21 of Set 10 | marsa matruh
# Processing Record 22 of Set 10 | umarizal
# Processing Record 23 of Set 10 | egvekinot
# Processing Record 24 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 25 of Set 10 | kavieng
# Processing Record 26 of Set 10 | qaqortoq
# Processing Record 27 of Set 10 | mahabad
# Processing Record 28 of Set 10 | ulan-ude
# Processing Record 29 of Set 10 | svetlaya
# Processing Record 30 of Set 10 | krasnogorsk
# Processing Record 31 of Set 10 | impfondo
# Processing Record 32 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 33 of Set 10 | klyuchi
# Processing Record 34 of Set 10 | mindelo
# Processing Record 35 of Set 10 | vitina
# Processing Record 36 of Set 10 | pontal do parana
# Processing Record 37 of Set 10 | pacific grove
# Processing Record 38 of Set 10 | katsuura
# Processing Record 39 of Set 10 | kimbe
# Processing Record 40 of Set 10 | college
# Processing Record 41 of Set 10 | cayenne
# Processing Record 42 of Set 10 | leninsk
# Processing Record 43 of Set 10 | komsomolskiy
# Processing Record 44 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 45 of Set 10 | loandjili
# Processing Record 46 of Set 10 | bairnsdale
# Processing Record 47 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 48 of Set 10 | saint-leu
# Processing Record 49 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 50 of Set 10 | nokaneng
# Processing Record 1 of Set 11 | axim
# Processing Record 2 of Set 11 | hobyo
# Processing Record 3 of Set 11 | ambulu
# Processing Record 4 of Set 11 | svetlyy
# Processing Record 5 of Set 11 | yeppoon
# Processing Record 6 of Set 11 | troitsko-pechorsk
# Processing Record 7 of Set 11 | moerai
# Processing Record 8 of Set 11 | zhanatas
# City not found. Skipping...
# Processing Record 9 of Set 11 | tanout
# Processing Record 10 of Set 11 | nanortalik
# Processing Record 11 of Set 11 | beyneu
# Processing Record 12 of Set 11 | new castle
# Processing Record 13 of Set 11 | ocampo
# Processing Record 14 of Set 11 | zhangye
# Processing Record 15 of Set 11 | bondo
# Processing Record 16 of Set 11 | atar
# Processing Record 17 of Set 11 | hasaki
# Processing Record 18 of Set 11 | nouadhibou
# Processing Record 19 of Set 11 | aripuana
# Processing Record 20 of Set 11 | elk plain
# Processing Record 21 of Set 11 | tura
# Processing Record 22 of Set 11 | demba
# Processing Record 23 of Set 11 | kenai
# Processing Record 24 of Set 11 | champerico
# Processing Record 25 of Set 11 | pangoa
# Processing Record 26 of Set 11 | chapayevka
# Processing Record 27 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 28 of Set 11 | longyearbyen
# Processing Record 29 of Set 11 | lae
# Processing Record 30 of Set 11 | port macquarie
# Processing Record 31 of Set 11 | thompson
# Processing Record 32 of Set 11 | ruteng
# Processing Record 33 of Set 11 | batticaloa
# Processing Record 34 of Set 11 | masuda
# Processing Record 35 of Set 11 | tiarei
# Processing Record 36 of Set 11 | lubao
# Processing Record 37 of Set 11 | aksarka
# Processing Record 38 of Set 11 | kysyl-syr
# Processing Record 39 of Set 11 | trincomalee
# Processing Record 40 of Set 11 | vaitape
# Processing Record 41 of Set 11 | businga
# Processing Record 42 of Set 11 | maloshuyka
# City not found. Skipping...
# Processing Record 43 of Set 11 | zacoalco
# City not found. Skipping...
# Processing Record 44 of Set 11 | ola
# Processing Record 45 of Set 11 | bhakkar
# Processing Record 46 of Set 11 | macaubas
# Processing Record 47 of Set 11 | ilebo
# Processing Record 48 of Set 11 | hovd
# Processing Record 49 of Set 11 | bolkhov
# Processing Record 50 of Set 11 | marsh harbour
# Processing Record 1 of Set 12 | nantucket
# Processing Record 2 of Set 12 | jumla
# Processing Record 3 of Set 12 | platteville
# Processing Record 4 of Set 12 | oktyabrskiy
# Processing Record 5 of Set 12 | acapulco
# Processing Record 6 of Set 12 | sao paulo de olivenca
# Processing Record 7 of Set 12 | tecoanapa
# Processing Record 8 of Set 12 | mitsamiouli
# Processing Record 9 of Set 12 | fort saint john
# City not found. Skipping...
# Processing Record 10 of Set 12 | cartagena del chaira
# Processing Record 11 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 12 of Set 12 | eureka
# Processing Record 13 of Set 12 | jalu
# Processing Record 14 of Set 12 | geresk
# City not found. Skipping...
# Processing Record 15 of Set 12 | hami
# Processing Record 16 of Set 12 | osakarovka
# Processing Record 17 of Set 12 | ardesen
# Processing Record 18 of Set 12 | shenjiamen
# Processing Record 19 of Set 12 | venado tuerto
# Processing Record 20 of Set 12 | burns lake
# Processing Record 21 of Set 12 | sangin
# Processing Record 22 of Set 12 | manzhouli
# Processing Record 23 of Set 12 | nishihara
# Processing Record 24 of Set 12 | alyangula
# Processing Record 25 of Set 12 | bagdarin
# Processing Record 26 of Set 12 | nemuro
# Processing Record 27 of Set 12 | filadelfia
# Processing Record 28 of Set 12 | knysna
# Processing Record 29 of Set 12 | guarapari
# Processing Record 30 of Set 12 | cururupu
# Processing Record 31 of Set 12 | sao jose da coroa grande
# Processing Record 32 of Set 12 | mutsu
# Processing Record 33 of Set 12 | valdivia
# Processing Record 34 of Set 12 | carutapera
# Processing Record 35 of Set 12 | grootfontein
# Processing Record 36 of Set 12 | uppsala
# Processing Record 37 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 38 of Set 12 | lompoc
# Processing Record 39 of Set 12 | garden city
# Processing Record 40 of Set 12 | panjwin
# City not found. Skipping...
# Processing Record 41 of Set 12 | teguise
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_url_df = pd.DataFrame(city_data)
city_url_df
# Out:
#                           City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0                       Atuona  -9.80 -139.03     81.39        75           0
# 1                         Hilo  19.73 -155.09     75.99        96          97
# 2                       Barrow  71.29 -156.79     -0.40        77          90
# 3                         Codo  -4.46  -43.89     74.59        95          71
# 4    Santa Isabel Do Rio Negro  -0.41  -65.02     80.04        60           7
# ..                         ...    ...     ...       ...       ...         ...
# 531               Grootfontein -19.57   18.12     70.02        60          46
# 532                    Uppsala  60.00   17.75     39.99        93          79
# 533                     Lompoc  34.64 -120.46     57.99        76           1
# 534                Garden City  42.33  -83.33     39.99        80          90
# 535                    Teguise  29.06  -13.56     53.60        71           0
#
#      Wind Speed Country                 Date       Current Conditions
# 0         17.92      PF  2020-01-15 01:20:32                clear sky
# 1          4.00      US  2020-01-15 01:15:44               light rain
# 2         25.28      US  2020-01-15 01:15:42          overcast clouds
# 3          2.44      BR  2020-01-15 01:20:33               light rain
# 4          2.26      BR  2020-01-15 01:20:33                clear sky
# ..          ...     ...                  ...                      ...
# 531        6.73      NA  2020-01-15 01:22:40         scattered clouds
# 532       10.29      SE  2020-01-15 01:22:40  light intensity drizzle
# 533       10.29      US  2020-01-15 01:19:53                clear sky
# 534        8.05      US  2020-01-15 01:22:41          overcast clouds
# 535        4.70      ES  2020-01-15 01:22:41                clear sky
#
# [536 rows x 10 columns]

# %%
print(city_weather)
# Out:
# {'coord': {'lon': -13.56, 'lat': 29.06}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 57.2, 'feels_like': 53.46, 'temp_min': 57.2, 'temp_max': 57.2, 'pressure': 1023, 'humidity': 71}, 'visibility': 10000, 'wind': {'speed': 5.82, 'deg': 360}, 'clouds': {'all': 0}, 'dt': 1579048567, 'sys': {'type': 1, 'id': 2379, 'country': 'ES', 'sunrise': 1579074533, 'sunset': 1579112254}, 'timezone': 0, 'id': 2510573, 'name': 'Teguise', 'cod': 200}
